# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # SQL numeric functions and aggregations

# %% [markdown]
# In this exercise, we will apply SQL numeric functions and aggregations to query a few tables in our Northwind database. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Be able to apply AVG, SUM, MAX, MIN, and COUNT functions.
# - Know how to aggregate data at different levels using the GROUP BY clause.
# - Understand how to  order and limit the results.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %% [markdown]
# Here is a view of all of our tables in the database:

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:500px";/>
# <br>
# <br>
#     <em>Figure 1: Northwind ERD</em>
# </div>

# %% [markdown]
# ## Exercise
#
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Display the average unit price of products in the 'Products' table.

# %%
# %%sql
# SELECT
#     AVG(UnitPrice) AS Average_Unit_Price
# FROM
#     Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(28.866363636363637,)]

# %% [markdown]
# ### Exercise 2
#
#
# Show the total quantity of products sold for each ProductID. Use the 'OrderDetails' table.

# %%
# %%sql
# SELECT
#     ProductID,
#     SUM(ProductID) AS Total_Quantity_Sold
# FROM
#     "Order Details"
# GROUP BY
#     ProductID;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(1, 7907),
#  (2, 15832),
#  (3, 23754),
#  (4, 31504),
#  (5, 39285),
#  (6, 47556),
#  (7, 55713),
#  (8, 63072),
#  (9, 70839),
#  (10, 79480),
#  (11, 86779),
#  (12, 95148),
#  (13, 103584),
#  (14, 109676),
#  (15, 119400),
#  (16, 126464),
#  (17, 134742),
#  (18, 141678),
#  (19, 152456),
#  (20, 159980),
#  (21, 164913),
#  (22, 175054),
#  (23, 183080),
#  (24, 189144),
#  (25, 197800),
#  (26, 207974),
#  (27, 212895),
#  (28, 222796),
#  (29, 227563),
#  (30, 238560),
#  (31, 246884),
#  (32, 250144),
#  (33, 262383),
#  (34, 269960),
#  (35, 276640),
#  (36, 286488),
#  (37, 290561),
#  (38, 300390),
#  (39, 310128),
#  (40, 316120),
#  (41, 324597),
#  (42, 329448),
#  (43, 340861),
#  (44, 346148),
#  (45, 353610),
#  (46, 362618),
#  (47, 365895),
#  (48, 378816),
#  (49, 389109),
#  (50, 393100),
#  (51, 403665),
#  (52, 411112),
#  (53, 414301),
#  (54, 427248),
#  (55, 437910),
#  (56, 440776),
#  (57, 454233),
#  (58, 458722),
#  (59, 470938),
#  (60, 475680),
#  (61, 485438),
#  (62, 490420),
#  (63, 496125),
#  (64, 505152),
#  (65, 513825),
#  (66, 530640),
#  (67, 527491),
#  (68, 531624),
#  (69, 551379),
#  (70, 561400),
#  (71, 558770),
#  (72, 569664),
#  (73, 576116),
#  (74, 583342),
#  (75, 594750),
#  (76, 602528),
#  (77, 609994)]

# %% [markdown]
# ### Exercise 3
#
#
# Find the maximum, minimum, and average freight from the 'Orders' table.

# %%
# %%sql
# SELECT
#     MIN(Freight) AS min_freight,
#     MAX(Freight) AS max_freight,
#     AVG(Freight) AS avg_freight
# FROM
#     Orders;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10.25, 587, 248.58558530893012)]

# %% [markdown]
# ### Exercise 4
#
# How many unique customers have made orders? Use the 'Orders' table.

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT CustomerID) AS Number_0f_customers
# FROM
#     Orders;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(93,)]

# %% [markdown]
# ### Exercise 5
#
# What is the total price for each order? You need to multiply the unit price by the quantity and subtract the discount for each order detail, then sum all the order details for each order. Use the 'OrderDetails' table.

# %%
# %%sql
# SELECT
#     OrderID,
#     SUM(UnitPrice*Quantity - Discount) AS TotalPrice
# FROM
#     "Order Details"
# GROUP BY
#     OrderID
# ORDER BY
#     OrderID;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 440.0),
#  (10249, 1863.4),
#  (10250, 1812.6999999999998),
#  (10251, 670.7),
#  (10252, 3729.8999999999996),
#  (10253, 1444.8000000000002),
#  (10254, 624.9),
#  (10255, 2490.5),
#  (10256, 517.8),
#  (10257, 1119.9),
#  (10258, 2018.0),
#  (10259, 100.8),
#  (10260, 1745.45),
#  (10261, 448.0),
#  (10262, 624.6),
#  (10263, 2464.05),
#  (10264, 724.35),
#  (10265, 1176.0),
#  (10266, 364.74999999999994),
#  (10267, 4030.7),
#  (10268, 1101.2),
#  (10269, 675.9000000000001),
#  (10270, 1376.0),
#  (10271, 48.0),
#  (10272, 1456.0),
#  (10273, 2142.2000000000003),
#  (10274, 538.6),
#  (10275, 307.1),
#  (10276, 420.0),
#  (10277, 1200.8),
#  (10278, 1488.8),
#  (10279, 467.75),
#  (10280, 613.2),
#  (10281, 86.5),
#  (10282, 155.39999999999998),
#  (10283, 1414.8),
#  (10284, 1451.25),
#  (10285, 2178.6),
#  (10286, 3016.0),
#  (10287, 923.7),
#  (10288, 88.8),
#  (10289, 479.4),
#  (10290, 2169.0),
#  (10291, 552.5),
#  (10292, 1296.0),
#  (10293, 848.7),
#  (10294, 1887.6),
#  (10295, 121.6),
#  (10296, 1050.6),
#  (10297, 1420.0),
#  (10298, 3126.5),
#  (10299, 349.5),
#  (10300, 608.0),
#  (10301, 755.0),
#  (10302, 2708.7999999999997),
#  (10303, 1241.7),
#  (10304, 954.4),
#  (10305, 4156.7),
#  (10306, 498.5),
#  (10307, 424.0),
#  (10308, 88.8),
#  (10309, 1762.0),
#  (10310, 336.0),
#  (10311, 268.79999999999995),
#  (10312, 1614.8),
#  (10313, 182.39999999999998),
#  (10314, 2326.7),
#  (10315, 516.8),
#  (10316, 2835.0),
#  (10317, 288.0),
#  (10318, 240.4),
#  (10319, 1191.2),
#  (10320, 516.0),
#  (10321, 144.0),
#  (10322, 112.0),
#  (10323, 164.4),
#  (10324, 6155.3),
#  (10325, 1497.0),
#  (10326, 982.0),
#  (10327, 2261.7),
#  (10328, 1168.0),
#  (10329, 4819.2),
#  (10330, 1939.6999999999998),
#  (10331, 88.5),
#  (10332, 2233.0),
#  (10333, 953.8),
#  (10334, 144.8),
#  (10335, 2544.3999999999996),
#  (10336, 316.7),
#  (10337, 2467.0),
#  (10338, 934.5),
#  (10339, 3463.1499999999996),
#  (10340, 2564.25),
#  (10341, 411.85),
#  (10342, 2300.0),
#  (10343, 1585.95),
#  (10344, 2855.75),
#  (10345, 2924.8),
#  (10346, 1731.1000000000001),
#  (10347, 927.7),
#  (11209, 17386.579999999998),
#  (11210, 39861.07),
#  (11211, 13424.02),
#  (11212, 51438.3),
#  (11213, 390.0),
#  (11214, 16038.710000000001),
#  (11215, 40365.42),
#  (11216, 23966.51),
#  (11217, 46906.77),
#  (11218, 3678.2),
#  (11219, 32996.54),
#  (11220, 42998.62),
#  (11221, 20952.81),
#  (11222, 53208.1),
#  (11223, 18169.85),
#  (11224, 31733.489999999998),
#  (11225, 42237.83),
#  (11226, 10592.54),
#  (11227, 18881.45),
#  (11228, 30700.92),
#  (11229, 31084.87),
#  (11230, 32166.82),
#  (11231, 2568.8999999999996),
#  (11232, 18327.89),
#  (11233, 21333.75),
#  (11234, 28968.3),
#  (11235, 15184.9),
#  (11236, 50355.5),
#  (11237, 49841.46),
#  (11238, 8635.75),
#  (11239, 9783.66),
#  (11240, 3362.5),
#  (11241, 18187.9),
#  (11242, 23427.37),
#  (11243, 22774.42),
#  (11244, 6731.9400000000005),
#  (11245, 19638.88),
#  (11246, 46208.85),
#  (11247, 8407.95),
#  ...]

# %% [markdown]
# ### Challenge question
#
# What are the 5 largest orders processed? (Hint: Use the 'OrderDetails' table.)

# %%
# %%sql
# SELECT
#     OrderID,
#     SUM(UnitPrice*Quantity*(1-Discount)) AS TotalPrice
# FROM
#     "Order Details"
# GROUP BY
#     OrderID
# ORDER BY
#     TotalPrice DESC
# LIMIT
#     5;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(13460, 73431.42),
#  (22571, 69796.71),
#  (21669, 69502.71),
#  (14425, 69353.99),
#  (12861, 69289.37)]

# %% [markdown]
# ### show table names

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Categories',),
#  ('sqlite_sequence',),
#  ('CustomerCustomerDemo',),
#  ('CustomerDemographics',),
#  ('Customers',),
#  ('Employees',),
#  ('EmployeeTerritories',),
#  ('Order Details',),
#  ('Orders',),
#  ('Products',),
#  ('Regions',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('Territories',)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# %%sql
#
# SELECT
#     AVG(UnitPrice)
# FROM
#     Products;

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# SELECT
#     ProductID,
#     SUM(Quantity) as TotalQuantity
# FROM
#     OrderDetails
# GROUP BY
#     ProductID;

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# SELECT
#     MAX(Freight) as MaxFreight,
#     MIN(Freight) as MinFreight,
#     AVG(Freight) as AvgFreight
# FROM
#     Orders;

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# SELECT
#     COUNT(DISTINCT CustomerID)
# FROM
#     Orders;

# %% [markdown]
# ### Exercise 5

# %%
# %%sql
#
# SELECT
#     OrderID,
#     SUM(UnitPrice * Quantity * (1 - Discount)) as TotalPrice
# FROM
#     OrderDetails
# GROUP BY
#     OrderID;

# %% [markdown]
# ### Challenge question

# %%
# %%sql
#
# SELECT
#     OrderID,
#     SUM(Quantity) as TotalQuantity
# FROM
#     OrderDetails
# GROUP BY
#     OrderID
# ORDER BY
#     TotalQuantity DESC
# LIMIT 5;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
